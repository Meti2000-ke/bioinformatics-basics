# %%
import pandas as pd

csvfile = "https://raw.githubusercontent.com/vappiah/bioinformatics-tutorials/refs/heads/main/python-tutorials/pandas-tutorials/tutorials/Episode-1/model_performance.csv"

# %%
df = pd.read_csv (csvfile)

# %%
df
# Out:
#       model  accuracy  precision  recall  f1score  cohenkappa_score  \
# 0  ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# 1       adb    0.7265     0.7539  0.7468   0.7495            0.4421
# 2        rf    0.7807     0.8044  0.7922   0.7961            0.5368
# 3       knn    0.6610     0.6945  0.6883   0.6910            0.3161
# 4        ng    0.7550     0.7762  0.7727   0.7741            0.5032
# 5        lr    0.7612     0.7933  0.7727   0.7791            0.4874
#
#    matthews_corrcoef
# 0             0.5425
# 1             0.4433
# 2             0.5405
# 3             0.3166
# 4             0.5037
# 5             0.4938

# %%
df.columns
# Out:
# Index(['model', 'accuracy', 'precision', 'recall', 'f1score',
#        'cohenkappa_score', 'matthews_corrcoef'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.shape 
# size of the table (number of rows and columns)
# Out:
# (6, 7)

# %%
# get basic statistics
df.describe()
# Out:
#        accuracy  precision    recall   f1score  cohenkappa_score  \
# count  6.000000   6.000000  6.000000  6.000000          6.000000
# mean   0.743850   0.770433  0.760817  0.764133          0.471017
# std    0.045084   0.041572  0.039262  0.039650          0.084018
# min    0.661000   0.694500  0.688300  0.691000          0.316100
# 25%    0.733625   0.759475  0.753275  0.755650          0.453425
# 50%    0.758100   0.784750  0.772700  0.776600          0.495300
# 75%    0.774325   0.798550  0.787325  0.791025          0.528400
# max    0.780700   0.804400  0.792200  0.796100          0.540500
#
#        matthews_corrcoef
# count           6.000000
# mean            0.473400
# std             0.084975
# min             0.316600
# 25%             0.455925
# 50%             0.498750
# 75%             0.531300
# max             0.542500

# %%
# get maximum value
df. max ()
# Out:
# model                    rf
# accuracy             0.7807
# precision            0.8044
# recall               0.7922
# f1score              0.7961
# cohenkappa_score     0.5405
# matthews_corrcoef    0.5425
# dtype: object

# %%
# set index
df.set_index("model")
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# ng                   0.5037
# lr                   0.4938

# %%
df
# Out:
#       model  accuracy  precision  recall  f1score  cohenkappa_score  \
# 0  ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# 1       adb    0.7265     0.7539  0.7468   0.7495            0.4421
# 2        rf    0.7807     0.8044  0.7922   0.7961            0.5368
# 3       knn    0.6610     0.6945  0.6883   0.6910            0.3161
# 4        ng    0.7550     0.7762  0.7727   0.7741            0.5032
# 5        lr    0.7612     0.7933  0.7727   0.7791            0.4874
#
#    matthews_corrcoef
# 0             0.5425
# 1             0.4433
# 2             0.5405
# 3             0.3166
# 4             0.5037
# 5             0.4938

# %%
# to change the table permanently to the indexed one
df.set_index("model" ,inplace = True)

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# ng                   0.5037
# lr                   0.4938

# %%
# df.max by default gives the maximum value of the columns.
# the other way to find the maximum  value of columns is:
df.max(axis=0)
# Out:
# accuracy             0.7807
# precision            0.8044
# recall               0.7922
# f1score              0.7961
# cohenkappa_score     0.5405
# matthews_corrcoef    0.5425
# dtype: float64

# %%
# to find the maximum value of rows
df.max(axis=1)
# Out:
# model
# ensemble    0.8003
# adb         0.7539
# rf          0.8044
# knn         0.6945
# ng          0.7762
# lr          0.7933
# dtype: float64

# %%
# get the overall maximum value
df.max().max()
# Out:
# 0.8044

# %%
# get the minimum value
df.min()
# Out:
# accuracy             0.6610
# precision            0.6945
# recall               0.6883
# f1score              0.6910
# cohenkappa_score     0.3161
# matthews_corrcoef    0.3166
# dtype: float64

# %%
# making plots 
df["accuracy"].plot(kind = 'bar')
# Out:
# <Axes: xlabel='model'>

# %%
df['precision'] .plot(kind = "pie")
# Out:
# <Axes: ylabel='precision'>

# %%
# making queries
# display model(s) with accuracy score greater than (>)0.77
df['accuracy']>0.77
# Out:
# model
# ensemble     True
# adb         False
# rf           True
# knn         False
# ng          False
# lr          False
# Name: accuracy, dtype: bool

# %%
df[ df['accuracy']>0.77]
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# rf                   0.5405

# %%
# display model(s) with accuracy score greater than (>)0.77 and f1score of (>) 0.7950

df["accuracy"]>0.77
df["f1score"]>0.7950

df[(df["accuracy"]>0.77) & (df["f1score"]>0.7950)]
# Out:
#        accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# rf       0.7807     0.8044  0.7922   0.7961            0.5368
#
#        matthews_corrcoef
# model
# rf                0.5405

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# ng                   0.5037
# lr                   0.4938

# %%
# adding new columns
error = 0.1, 0.35, 0.58, 0.0089, 1.8, 2.6

df['error'] = error

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef   error
# model
# ensemble             0.5425  0.1000
# adb                  0.4433  0.3500
# rf                   0.5405  0.5800
# knn                  0.3166  0.0089
# ng                   0.5037  1.8000
# lr                   0.4938  2.6000

# %%
# adding new row
ann = 0.864, 0.25, 0.789, 0.985, 0.146, 2.56, 1.978
df.loc['ann'] = ann

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460
#
#           matthews_corrcoef   error
# model
# ensemble             0.5425  0.1000
# adb                  0.4433  0.3500
# rf                   0.5405  0.5800
# knn                  0.3166  0.0089
# ng                   0.5037  1.8000
# lr                   0.4938  2.6000
# ann                  2.5600  1.9780

# %%
# remove/drop columns
#approach 1
del df['error']

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# ng                   0.5037
# lr                   0.4938
# ann                  2.5600

# %%
# approach 2
df.drop(['matthews_corrcoef'], axis = 1)
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460

# %%
# to change the table permanently:
newdf = df.drop(['matthews_corrcoef'], axis = 1)

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# ng                   0.5037
# lr                   0.4938
# ann                  2.5600

# %%
# or we can use the implace = true function but if we use implace becareful we cannot change it back to the original
df.drop(['matthews_corrcoef'], axis = 1, inplace = True)

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460

# %%
# to drop two columns at once:
df.drop(['precision','recall'],axis = 1)
# Out:
#           accuracy  f1score  cohenkappa_score
# model
# ensemble    0.7787   0.7950            0.5405
# adb         0.7265   0.7495            0.4421
# rf          0.7807   0.7961            0.5368
# knn         0.6610   0.6910            0.3161
# ng          0.7550   0.7741            0.5032
# lr          0.7612   0.7791            0.4874
# ann         0.8640   0.9850            0.1460

# %%
# remove/drop rows
df.drop(['ann'], axis =0)
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874

# %%
# rename columns

df.rename ({"cohenkappa_score": "ck_score"}, axis =1)
# Out:
#           accuracy  precision  recall  f1score  ck_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950    0.5405
# adb         0.7265     0.7539  0.7468   0.7495    0.4421
# rf          0.7807     0.8044  0.7922   0.7961    0.5368
# knn         0.6610     0.6945  0.6883   0.6910    0.3161
# ng          0.7550     0.7762  0.7727   0.7741    0.5032
# lr          0.7612     0.7933  0.7727   0.7791    0.4874
# ann         0.8640     0.2500  0.7890   0.9850    0.1460

# %%
# rename rows 

df.rename ({"ng":"nb"}, axis = 0)
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460

# %%
# if I want to make the name change permanent:

df.rename ({"ng":"nb"}, axis = 0, inplace = True)

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460

# %%
# subsets
df["accuracy"]
# Out:
# model
# ensemble    0.7787
# adb         0.7265
# rf          0.7807
# knn         0.6610
# nb          0.7550
# lr          0.7612
# ann         0.8640
# Name: accuracy, dtype: float64

# %%
df [ ["accuracy","precision"] ]
# Out:
#           accuracy  precision
# model
# ensemble    0.7787     0.8003
# adb         0.7265     0.7539
# rf          0.7807     0.8044
# knn         0.6610     0.6945
# nb          0.7550     0.7762
# lr          0.7612     0.7933
# ann         0.8640     0.2500

# %%
df.loc [:,:]
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# ann         0.8640     0.2500  0.7890   0.9850            0.1460

# %%
df.loc[:,['accuracy']]
# Out:
#           accuracy
# model
# ensemble    0.7787
# adb         0.7265
# rf          0.7807
# knn         0.6610
# nb          0.7550
# lr          0.7612
# ann         0.8640

# %%
df.loc[:,['accuracy', 'precision']]
# Out:
#           accuracy  precision
# model
# ensemble    0.7787     0.8003
# adb         0.7265     0.7539
# rf          0.7807     0.8044
# knn         0.6610     0.6945
# nb          0.7550     0.7762
# lr          0.7612     0.7933
# ann         0.8640     0.2500

# %%
df.loc[['ensemble'],:]
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score
# model
# ensemble    0.7787     0.8003  0.7922    0.795            0.5405

# %%
df.loc ['ensemble','accuracy']
# Out:
# 0.7787

# %%
# save data to an output csv file
subset = df[['accuracy', 'precision']]

# %%
subset
# Out:
#           accuracy  precision
# model
# ensemble    0.7787     0.8003
# adb         0.7265     0.7539
# rf          0.7807     0.8044
# knn         0.6610     0.6945
# nb          0.7550     0.7762
# lr          0.7612     0.7933
# ann         0.8640     0.2500

# %%
subset.to_csv("subset.csv")

# %%
# to know where python saved it

import os
os.getcwd()
# Out:
# 'c:\\Users\\dell\\Desktop\\Python stuffs'

# %% [markdown]
# # New Tutorial on Pandas

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7,8,9,]])

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# to add columns
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7,8,9,]], columns = ['A','B','C'])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# to add rows named as index?
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7,8,9,]], columns = ['A','B','C'], index = ['X', 'Y', 'Z'])
df
# Out:
#    A  B  C
# X  1  2  3
# Y  4  5  6
# Z  7  8  9

# %%
# to get information about the table 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, X to Z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
# to get the statistics
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0
